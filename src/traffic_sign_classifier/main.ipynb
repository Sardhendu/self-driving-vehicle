# %%
# Imports;
import sys
sys.path.insert(0, '../..')

import numpy as np
import tensorflow as tf
from src import commons

# %%
train_data_path = './data/train.p'
eval_data_path = './data/valid.p'
test_data_path = './data/test.p'

# %%
data = commons.read_pickle(train_data_path)
features = data["features"]
labels = data["labels"]
print("Feature: ", features.shape)
print("labels: ", labels.shape)
# Out:
# Feature:  (34799, 32, 32, 3)
# labels:  (34799,)

# %%
data = commons.read_pickle(eval_data_path)
features = data["features"]
labels = data["labels"]
print("Feature: ", features.shape)
print("labels: ", labels.shape)
# Out:
# Feature:  (4410, 32, 32, 3)
# labels:  (4410,)

# %%
data = commons.read_pickle(test_data_path)
features = data["features"]
labels = data["labels"]
print("Feature: ", features.shape)
print("labels: ", labels.shape)
# Out:
# Feature:  (12630, 32, 32, 3)
# labels:  (12630,)

# %% [markdown]
# ## Class Distribution

# %%
from collections import Counter
label_cnt = Counter(labels)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20, 10), facecolor="w")
plt.bar(label_cnt.keys(), label_cnt.values())
# Out:
# <BarContainer object of 43 artists>
